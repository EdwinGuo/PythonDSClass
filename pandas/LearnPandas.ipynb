# %%
#Loading data
# Credit: Machine Learning with Python Cookbook by Chris Albon
#https://www.safaribooksonline.com/library/view/machine-learning-with/9781491989371/ch02.html#loading-data

# 1) Load scikit-learn's datasets
from sklearn import datasets

# Load digits dataset
digits = datasets.load_digits()

# Create features matrix
features = digits.data

# Create target vector
target = digits.target

# View first observation
features


#load_boston
## Contains 503 observations on Boston housing prices. It is a good dataset for exploring regression algorithms.
#load_iris
## Contains 150 observations on the measurements of Iris flowers. It is a good dataset for exploring classification algorithms.
#load_digits
##Contains 1,797 observations from images of handwritten digits. It is a good dataset for teaching image classification.
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
# Load csv
import pandas as pd

# Directly read a file
dataframe = pd.read_csv("../pandas/bike.csv")
# View first two rows
dataframe.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
# Or read from a url
pd.read_csv('https://raw.githubusercontent.com/EdwinGuo/PythonDSClass/master/pandas/bike_hour.csv').head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
# Loading a JSON File

import pandas as pd

# Load data
dataframe = pd.read_json('../pandas/movie_ratings.json', orient='columns')

# View the first two rows
dataframe.head(5)
# Out:
#                   Alex Roberts  Jillian Hobart  John Carson  Melissa Jones  \
# Anger Management           NaN             3.0          3.0              2
# Fracture                   5.0             4.0          3.5              3
# Inception                  3.0             NaN          2.5              3
# Jerry Maguire              3.0             4.5          3.0              3
# Pulp Fiction               4.0             3.5          3.5              4
#
#                   Michael Henry  Michelle Peterson  William Reynolds
# Anger Management            NaN                1.5               NaN
# Fracture                    4.0                5.0               3.5
# Inception                   NaN                3.0               2.5
# Jerry Maguire               NaN                3.0               4.0
# Pulp Fiction                4.5                3.5               3.0

# %%
# Querying a SQL Database

import pandas as pd
from sqlalchemy import create_engine

# Create a connection to the database
database_connection = create_engine('sqlite:///people.db')

# Load data
dataframe = pd.read_sql_query('SELECT * FROM people', database_connection)

# View first two rows
dataframe.head(4)
# Out:
#    name  age     city
# 0  John   25   Ottawa
# 1   Dan   22  Toronto
# 2  Lucy   32  Toronto
# 3  Alex   32   London

# %%
# DataFrame manipulation

# Load library
import pandas as pd

# Create URL
url = 'https://tinyurl.com/titanic-csv'

# Load data as a dataframe
dataframe = pd.read_csv(url)

# Show first 5 rows
dataframe.head(10)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
# 5                             Anderson, Mr Harry    1st  47.00    male
# 6               Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 7                         Andrews, Mr Thomas, jr    1st  39.00    male
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# 9                         Artagaveytia, Mr Ramon    1st  71.00    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0
# 5         1        0
# 6         1        1
# ...

# %%
# Creating a Data Frame

import pandas as pd

# Create DataFrame
dataframe = pd.DataFrame()

# Add columns
dataframe['Name'] = ['Jacky Jackson', 'Steven Stevenson']
dataframe['Age'] = [38, 25]
dataframe['Driver'] = [True, False]

# Show DataFrame
dataframe
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False

# %%
# continue

# Create row
new_person = pd.Series(['Molly Mooney', 40, True], index=['Name','Age','Driver'])

# Append row
dataframe.append(new_person, ignore_index=True)
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False
# 2      Molly Mooney   40    True

# %%
# Describing the Data

# Load library
import pandas as pd

# Create URL
url = 'https://tinyurl.com/titanic-csv'

# Load data
dataframe = pd.read_csv(url)

dataframe.shape
# Out:
# (1313, 6)

# %%
# continue

# Show statistics
dataframe.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %%
# Navigating DataFrames
# Load library
import pandas as pd

# Select first row
dataframe.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                   29
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
# Select three rows
dataframe.iloc[1:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Select first four rows
dataframe.iloc[:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Set index
dataframe = dataframe.set_index(dataframe['Name'])

# Show row
dataframe.loc['Allen, Miss Elisabeth Walton']
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                   29
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: Allen, Miss Elisabeth Walton, dtype: object

# %%
# Selecting Rows Based on Conditionals

dataframe[dataframe['Sex'] == 'female'].head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1

# %%
# Filter rows
dataframe[(dataframe['Sex'] == 'female') & (dataframe['Age'] >= 65)]
# Out:
#                                                                                                  Name  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...  Crosby, Mrs Edward Gifford (Catherine Elizabet...
#
#                                                    PClass   Age     Sex  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...    1st  69.0  female
#
#                                                     Survived  SexCode
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...         1        1

# %%
# Replacing Values

# Replace values, show two rows
dataframe['Sex'].replace("female", "Woman").head(2)
# Out:
# Name
# Allen, Miss Elisabeth Walton    Woman
# Allison, Miss Helen Loraine     Woman
# Name: Sex, dtype: object

# %%
# Replace "female" and "male with "Woman" and "Man"
dataframe['Sex'].replace(["female", "male"], ["Woman", "Man"]).head(5)
# Out:
# Name
# Allen, Miss Elisabeth Walton                     Woman
# Allison, Miss Helen Loraine                      Woman
# Allison, Mr Hudson Joshua Creighton                Man
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    Woman
# Allison, Master Hudson Trevor                      Man
# Name: Sex, dtype: object

# %%
# Replace values, show two rows
dataframe.replace(1, "One").head(2)
# Out:
#                                                       Name PClass Age     Sex  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29  female
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2  female
#
#                              Survived SexCode
# Name
# Allen, Miss Elisabeth Walton      One     One
# Allison, Miss Helen Loraine         0     One

# %%
# Replace values, show two rows
dataframe.replace(r"1st", "First", regex=True).head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton  First  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine  First   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1

# %%
# Renaming Columns

# Rename column, show two rows
dataframe.rename(columns={'PClass': 'Passenger Class'}).head(2)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine             1st
#
#                                Age     Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1
# Allison, Miss Helen Loraine    2.0  female         0        1

# %%
# Rename columns, show two rows
dataframe.rename(columns={'PClass': 'Passenger Class', 'Sex': 'Gender'}).head(2)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine             1st
#
#                                Age  Gender  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1
# Allison, Miss Helen Loraine    2.0  female         0        1

# %%
# Finding the Minimum, Maximum, Sum, Average, and Count

# Calculate statistics
print('Maximum:', dataframe['Age'].max())
print('Minimum:', dataframe['Age'].min())
print('Mean:', dataframe['Age'].mean())
print('Sum:', dataframe['Age'].sum())
print('Count:', dataframe['Age'].count())
# Out:
# ('Maximum:', 71.0)
# ('Minimum:', 0.17)
# ('Mean:', 30.397989417989415)
# ('Sum:', 22980.88)
# ('Count:', 756)

# %%
# Show counts
dataframe.count()
# Out:
# Name        1313
# PClass      1313
# Age          756
# Sex         1313
# Survived    1313
# SexCode     1313
# dtype: int64

# %%
# filter the rows that with age is null

dataframe[dataframe['Age'].isnull()].head(10)
# Out:
#                                                                                                  Name  \
# Name
# Aubert, Mrs Leontine Pauline                                             Aubert, Mrs Leontine Pauline
# Barkworth, Mr Algernon H                                                     Barkworth, Mr Algernon H
# Baumann, Mr John D                                                                 Baumann, Mr John D
# Borebank, Mr John James                                                       Borebank, Mr John James
# Bradley, Mr George                                                                 Bradley, Mr George
# Brewe, Dr Arthur Jackson                                                     Brewe, Dr Arthur Jackson
# Calderhead, Mr Edward P                                                       Calderhead, Mr Edward P
# Carrau, Mr Francisco M                                                         Carrau, Mr Francisco M
# ...

# %%
# filter the rows that with age is not null

dataframe[dataframe['Age'].notnull()].head(10)
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
# Anderson, Mr Harry                                                        Anderson, Mr Harry
# Andrews, Miss Kornelia Theodosia                            Andrews, Miss Kornelia Theodosia
# Andrews, Mr Thomas, jr                                                Andrews, Mr Thomas, jr
# Appleton, Mrs Edward Dale (Charlotte Lamson)    Appleton, Mrs Edward Dale (Charlotte Lamson)
# ...

# %%
# Finding Unique Values

# Select unique values
dataframe['Sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# Show counts
dataframe['Sex'].value_counts()
# Out:
# male      851
# female    462
# Name: Sex, dtype: int64

# %%
# Show counts
dataframe['PClass'].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: PClass, dtype: int64

# %%
# Deleting a Column

# Delete column
dataframe.drop('Age', axis=1).head(2)
# Out:
#                                                       Name PClass     Sex  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  female
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st  female
#
#                               Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton         1        1
# Allison, Miss Helen Loraine          0        1

# %%
dataframe.count()
# Out:
# Name        1313
# PClass      1313
# Age          756
# Sex         1313
# Survived    1313
# SexCode     1313
# dtype: int64

# %%
# Deleting a Row

# Delete rows, show first two rows of output
dataframe[dataframe['Sex'] != 'male'].head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1

# %%
# Delete row, show first two rows of output
dataframe[dataframe['Name'] != 'Allison, Miss Helen Loraine'].head(2)
# Out:
#                                                                     Name  \
# Name
# Allen, Miss Elisabeth Walton                Allen, Miss Elisabeth Walton
# Allison, Mr Hudson Joshua Creighton  Allison, Mr Hudson Joshua Creighton
#
#                                     PClass   Age     Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton           1st  29.0  female         1        1
# Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
# Delete row, show first two rows of output
dataframe[dataframe.index != 0].head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1

# %%
# Dropping Duplicate Rows

# Drop duplicates, show first two rows of output
dataframe.drop_duplicates().head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1
